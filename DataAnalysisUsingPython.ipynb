# %%
import numpy as np
points = np.arange(-5, 5, 0.01)
xs, ys = np.meshgrid(points, points)
z = np.sqrt(xs**2 + ys**2)

# %%
import matplotlib.pyplot as plt
plt.imshow(z, cmap=plt.cm.gray); plt.colorbar()
plt.title("Image plot of $\sqrt{x^2 + y^2}$ for a grid of values")
# Out:
# Text(0.5, 1.0, 'Image plot of $\\sqrt{x^2 + y^2}$ for a grid of values')

# %%
from random import normalvariate
N = 1000000
# %timeit samples = [normalvariate(0, 1) for _ in range(N)]
# Out:
# 1.6 s ± 53.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit np.random.normal(size=N)
# Out:
# 76.6 ms ± 1.09 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
import random
position = 0
walk = [position]
steps = 1000
for i in range(steps):
    step = 1 if random.randint(0, 1) else -1
    position += step
    walk.append(position)

# %%
plt.plot(walk[:100])

# %%
nsteps = 1000
draws = np.random.randint(0, 2, size=nsteps)
steps = np.where(draws > 0, 1, -1)
walk = steps.cumsum()

# %%
walk.min()
# Out:
# -44

# %%
(np.abs(walk) >= 10).argmax()
# Out:
# 127

# %%
import pandas as pd
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isnull(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
import pandas_datareader.data as web
all_data = {ticker: web.get_data_yahoo(ticker) for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']}
price = pd.DataFrame({ticker: data['Adj Close'] for ticker, data in all_data.items()})
volume = pd.DataFrame({ticker: data['Volume'] for ticker, data in all_data.items()})

# %%
returns = price.pct_change()

# %%
returns.tail()
# Out:
#                 AAPL       IBM      MSFT      GOOG
# Date
# 2020-07-09  0.004300 -0.016991  0.007001  0.010020
# 2020-07-10  0.001749  0.022816 -0.003033  0.020351
# 2020-07-13 -0.004613  0.007182 -0.030889 -0.019718
# 2020-07-14  0.016548  0.011745  0.006181  0.006114
# 2020-07-15  0.006253  0.018740 -0.005136 -0.006054

# %%
returns['MSFT'].corr(returns['IBM'])
# Out:
# 0.5907959604692935

# %%
returns['MSFT'].cov(returns['IBM'])
# Out:
# 0.00016616838132743424

# %%
returns.MSFT.corr(returns.IBM)
# Out:
# 0.5907959604692935

# %%
returns.corr()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  1.000000  0.527155  0.715653  0.666262
# IBM   0.527155  1.000000  0.590796  0.539061
# MSFT  0.715653  0.590796  1.000000  0.779925
# GOOG  0.666262  0.539061  0.779925  1.000000

# %%
returns.cov()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  0.000333  0.000156  0.000227  0.000202
# IBM   0.000156  0.000262  0.000166  0.000145
# MSFT  0.000227  0.000166  0.000302  0.000226
# GOOG  0.000202  0.000145  0.000226  0.000277

# %%
returns.corrwith(returns.IBM)
# Out:
# AAPL    0.527155
# IBM     1.000000
# MSFT    0.590796
# GOOG    0.539061
# dtype: float64

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])

# %%
uniques = obj.unique()
uniques
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
# !cat /home/pamba/Desktop/HomeLearning/Python/PythonForDataAnalysis/examples/ex1.csv
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %%
df = pd.read_csv('/home/pamba/Desktop/HomeLearning/Python/PythonForDataAnalysis/examples/ex1.csv')

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df = pd.read_table('/home/pamba/Desktop/HomeLearning/Python/PythonForDataAnalysis/examples/ex1.csv', sep=',')

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo
